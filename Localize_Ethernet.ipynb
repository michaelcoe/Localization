# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import socket
import numpy as np
import math as mt
import matplotlib.pyplot as plt
import localization as loc
 
BROADCAST_PORT = 58083
 
s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
s.bind(('0.0.0.0', BROADCAST_PORT))

# %%
while(1):
    val = s.recvfrom(5120)
    data =  np.fromstring(val[0], dtype='H')
    times = data[0:512]
    mic1 = data[512:1024]*(3300.0/65535.0)
    mic2 = data[1024:1536]*(3300.0/65535.0)
    mic3 = data[1536:2048]*(3300.0/65535.0)
    mic4 = data[2048:2560]*(3300.0/65535.0)
    
    m1, m2, m3, m4 = loc.interpolate(mic1, mic2, mic3, mic4, 10)
    cor1, cor2, cor3, cor4 = loc.correlate(m1, m2, m3, m4)
    sampleRate = len(times)/(times[len(times)]*mt.pow(10,-6)
    t1, t2, t3, t4 = loc.get_taus(cor1, cor2, cor3, cor4, sampleRate)
    location = loc.tdoa(t1, t2, t3, t4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2275883c87f9> in <module>()
#      11     plt.ylabel('Voltage [mv]',fontsize=18)
#      12     plt.title('ADC Full Speed 3kHz Sampling')
# ---> 13     plt.show()
#
# /home/interam/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in show(*args, **kw)
#     143     """
#     144     global _show
# --> 145     _show(*args, **kw)
#     146
#     147
#
# /home/interam/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/pylab/backend_inline.pyc in show(close)
#      41     try:
#      42         for figure_manager in Gcf.get_all_fig_managers():
# ---> 43             display(figure_manager.canvas.figure)
#      44     finally:
#      45         show._to_draw = []
#
# /home/interam/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc in display(*objs, **kwargs)
# ...
